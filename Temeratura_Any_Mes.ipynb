# %%
import pandas as pd
from matplotlib import pyplot

# %%
df=pd.read_csv("Desktop/pythonstuff/ex.csv")

# %%
mean08=df[:].mean()

# %%
mean08
# Out:
# Any                      1899.000000
# Temp_Mitjana_Gener          7.653138
# Temp_Mitjana_Febrer         8.529289
# Temp_Mitjana_Marc          10.274059
# Temp_Mitjana_Abril         12.445607
# Temp_Mitjana_Maig          15.891632
# Temp_Mitjana_Juny          19.583264
# Temp_Mitjana_Juliol        22.462343
# Temp_Mitjana_Agost         22.592887
# Temp_Mitjana_Setembre      19.795816
# Temp_Mitjana_Octubre       15.799163
# Temp_Mitjana_Novembre      11.157322
# Temp_Mitjana_Desembre       8.313808
# dtype: float64

# %%
df.describe()
# Out:
#                Any  Temp_Mitjana_Gener  Temp_Mitjana_Febrer  \
# count   239.000000          239.000000           239.000000
# mean   1899.000000            7.653138             8.529289
# std      69.137544            1.487900             1.589957
# min    1780.000000            3.400000             2.500000
# 25%    1839.500000            6.700000             7.700000
# 50%    1899.000000            7.700000             8.600000
# 75%    1958.500000            8.800000             9.500000
# max    2018.000000           10.700000            12.500000
#
#        Temp_Mitjana_Marc  Temp_Mitjana_Abril  Temp_Mitjana_Maig  \
# count         239.000000          239.000000         239.000000
# mean           10.274059           12.445607          15.891632
# std             1.392204            1.245821           1.446356
# min             6.100000            9.400000          11.500000
# 25%             9.500000           11.500000          14.900000
# ...

# %%
df2=df.drop(["Any"], axis=1)
#nou df sense columna d'any

# %%
df2
# Out:
#      Temp_Mitjana_Gener  Temp_Mitjana_Febrer  Temp_Mitjana_Marc  \
# 0                   6.7                  7.3               11.6
# 1                   7.5                  8.9               10.9
# 2                   8.2                  6.1                9.8
# 3                   8.3                  8.6                9.6
# 4                   7.3                  7.1               10.8
# ..                  ...                  ...                ...
# 234                 9.8                 10.1               12.3
# 235                 9.1                  8.2               12.0
# 236                10.7                 11.3               11.1
# 237                 7.9                 11.4               13.3
# 238                10.5                  6.7               10.8
#
#      Temp_Mitjana_Abril  Temp_Mitjana_Maig  Temp_Mitjana_Juny  \
# 0                  11.4               16.3               19.1
# 1                  13.7               16.8               18.0
# ...

# %%
mean09=df2.mean(axis=1)
#mitjana de temperatures per fila

# %%
mean09
# Out:
# 0      14.075000
# 1      14.716667
# 2      13.633333
# 3      14.400000
# 4      13.616667
#          ...
# 234    16.275000
# 235    16.600000
# 236    16.475000
# 237    16.375000
# 238    16.283333
# Length: 239, dtype: float64

# %%
matplotlib.pyplot.plot(df["Any"], mean09)

# %%
matplotlib.pyplot.plot(df["Any"], df["Temp_Mitjana_Maig"])

# %%
matplotlib.pyplot.plot(df["Any"], df["Temp_Mitjana_Gener"])

# %%
matplotlib.pyplot.plot(df["Any"], df["Temp_Mitjana_Agost"])
